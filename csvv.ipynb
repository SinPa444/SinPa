# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import random as rd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dataset = pd.read_csv("./titanic.csv")

# %%
del dataset["PassengerId"]
del dataset["Name"]

# %%
feature = dataset.iloc[:, :-1]
label = dataset.iloc[:, -1]

# %%
feature["Age"].fillna(feature["Age"].mean(), inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12500\3707518515.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feature["Age"].fillna(feature["Age"].mean(), inplace=True)

# %%
feature["Cabin"].fillna(0, inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12500\2086925296.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   feature["Cabin"].fillna(0, inplace=True)

# %%
label.fillna("S", inplace=True)

# %%
one_feature = pd.get_dummies(feature, dtype=int)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit_transform(one_feature)
# Out:
# array([[0.        , 1.        , 0.27117366, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.4722292 , ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 1.        , 0.32143755, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 1.        , 0.36792055, ..., 0.        , 0.        ,
#         0.        ],
#        [1.        , 0.        , 0.32143755, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 1.        , 0.39683338, ..., 0.        , 0.        ,
#         0.        ]])

# %%
x_tr, x_ts, y_tr, y_ts = train_test_split(one_feature, label, test_size=0.2)

# %%
model1 = SVC()

# %%
model1.fit(x_tr, y_tr)
# Out:
# SVC()

# %%
model2 = DecisionTreeClassifier()

# %%
model2.fit(x_tr, y_tr)
# Out:
# DecisionTreeClassifier()

# %%
model3 = MLPClassifier(hidden_layer_sizes=(150,150,150))

# %%
model3.fit(x_tr, y_tr)
# Out:
# MLPClassifier(hidden_layer_sizes=(150, 150, 150))

# %%
pred1 = model1.predict(x_ts)

# %%
pred2 = model2.predict(x_ts)

# %%
pred3 = model3.predict(x_ts)

# %%
print(accuracy_score(pred1, y_ts))
print(confusion_matrix(pred1, y_ts))
# Out:
# 0.7262569832402235
# [[  0   0   0]
#  [  0   0   0]
#  [ 38  11 130]]

# %%
print(accuracy_score(pred2, y_ts))
print(confusion_matrix(pred2, y_ts))
# Out:
# 0.88268156424581
# [[ 24   0   2]
#  [  0   6   0]
#  [ 14   5 128]]

# %%
print(accuracy_score(pred3, y_ts))
print(confusion_matrix(pred3, y_ts))
# Out:
# 0.8156424581005587
# [[ 15   2   2]
#  [  0   7   4]
#  [ 23   2 124]]
